# %% [markdown]
# <a href="https://colab.research.google.com/github/mykahbyte/CPE-310---IE22S1/blob/main/Rubis_Seatwork_1_3_Functions%2C_Loops%2C_and_iterations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Seatwork 1.3: Functions, Loops, and iterations**
# **Seatwork 1.3: Function** <br>
# ***Name***: Mykah Angela Rubis <br>
# ***Course & Section***: CPE 310 - IE22S1 <br>
# ***Course name***: Fundamental of Data Science <br>
# ***Date***: January 08, 2026 <br>

# %% [markdown]
# # **MODULE 1**

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
type("Hello Worldd")
# Out:
# str

# %%
type(12)
# Out:
# int

# %% [markdown]
# data types

# %%
mesage = """" This
message spans
three lines"""

# %%
message = """ph level;
temperature
yiepie"""

# %% [markdown]
# tripple quotations (single/double)

# %%
42,670
# Out:
# (42, 670)

# %%
4267
# Out:
# 4267

# %%
day = "thursday"
print(day)
day = "friday"
print(day)
day = 21
print(day)
# Out:
# thursday
# friday
# 21

# %% [markdown]
# underscore is considered as character
# standard for spaces

# %%
len("hello")
# Out:
# 5

# %%
7/4
# Out:
# 1.75

# %%
7//4
# Out:
# 1

# %%
7%3
# Out:
# 1

# %%
data_1 = 123
data_1 = str(data_1)
type(data_1)
# Out:
# str

# %%
data_2 = int(data_1)
type(data_2)
# Out:
# int

# %%
2*3-1
# Out:
# 5

# %%
2**3**1
# Out:
# 8

# %%
"banana" + " nut"
# Out:
# 'banana nut'

# %%
"mykah" * 3
# Out:
# 'mykahmykahmykah'

# %%
stud = input("Fill in the blank. 1, 2 ,3 ___?")
print ("1, 2, 3... " + stud + ". I wish that heaven has a phone to call you up")
# Out:
# Fill in the blank. 1, 2 ,3 ___?release em
# 1, 2, 3... release em. I wish that heaven has a phone to call you up

# %%
radius = float(input("Give me a radius: "))
print(3.14 * radius ** 2)
# Out:
# Give me a radius: 1
# 3.14

# %%
total_secs = int(input("How many seconds? "))
hours = total_secs // 3600
remaining = total_secs % 3600
minutes = remaining // 60
seconds = remaining % 60
print ("Hrs = " + str(hours) + "\n Mins = " + str(minutes) + "\n Secs = " + str(seconds))
# Out:
# How many seconds? 1
# Hrs = 0
#  Mins = 0
#  Secs = 1

# %%
inp = input('Enter Fahrenheit Temperature: ')
try:
  fahr = float(inp)
  cel = (fahr - 32.0) * 5.0 / 9.0
  print(cel)
except:
  print('Please enter a number')
# Out:
# Enter Fahrenheit Temperature: 2
# -16.666666666666668

# %% [markdown]
# # ***MODULE 2***

# %% [markdown]
# While - as long as the condition is true
# For - has specific ...

# %%
age = int(input("How old are you?: "))
if age >= 18:
  print("haha matanda.")
else:
  print("bata")
# Out:
# How old are you?: 20
# haha matanda.

# %% [markdown]
# list = [,]
# tuples = ("",)
# dictionary {}
# set

# %%
print("For loop:")
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
  print("-", fruit)
# Out:
# For loop:
# - apple
# - banana
# - cherry

# %%
print("\nWhile loop:")
count = 1
while count <= 5:
  print("Count", count)
  count += 1
# Out:
# While loop:
# Count 1
# Count 2
# Count 3
# Count 4
# Count 5

# %%
for i in range(1,6):
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %% [markdown]
# continue - iteration was skipped

# %%
for i in range(1,6):
  if i == 3:
    break
  print(i)
# Out:
# 1
# 2

# %% [markdown]
# break - stopped the loop

# %% [markdown]
# # MODULE 3

# %% [markdown]
# FUNCTION
# built in funtions
#
# *   built in funtions
# - print()
#
# * modules
# - range
#
# *
# - def message()
#
# invocation
# - function call
#
# Jump
# -remembers the location
#
# Execution
# - executed step by step
#
# Return
# - return after the invocation

# %%
def introduce (name, age, course):
  print(f"My name is {name}, I am {age} years old, and I study {course}.")

name1 = input("Enter your name: ")
age1 = input("Enter your age: ")
course1 = input("Enter your course: ")


introduce(name1, age1, course1)
# Out:
# Enter your name: Mykah
# Enter your age: 99
# Enter your course: IE
# My name is Mykah, I am 99 years old, and I study IE.
